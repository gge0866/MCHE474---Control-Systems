# %%
import control
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

# %% [markdown]
# # P7.1
# ## a.

# %%
# the control library's root_locus() function wants the G(s) of 1+KG(s)=0

s=control.TransferFunction.s # now just code the TF however it is written

Ga = (1)/(s*(s+5)*(s+20))
_ = control.root_locus(Ga)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ## b.

# %%
Gb = (1)/((s**2+2*s+2)*(s+2))
_ = control.root_locus(Gb)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ## c.

# %%
Gc = (s+10)/(s*(s+1)*(s+20))
_ = control.root_locus(Gc)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ## d.

# %%
Gd = (s**2+4*s+8)/(s**2*(s+1))
_ = control.root_locus(Gd)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# # P7.5
# ## (a)
#
# The closed-loop TF for the automatic control loop ignoring the disturbance (for now) is:
#
# $$T(s)=\frac{G(s)}{1+G(s)\frac{K_2(s+1)}{s+9}}$$
#
# where:
#
# $$G(s)=\frac{25(s+0.03)}{(s+0.4)(s^2-0.36s+0.16)}$$
#
# The characteristic equation that we will use for the root locus is:
#
# $$1+K_s\frac{25(s+0.03)}{(s+0.4)(s^2-0.36s+0.16)}\frac{(s+1)}{s+9}=0$$

# %%
sys_auto = (25*(s+0.03)*(s+1))/((s+0.4)*(s**2-0.36*s+0.16)*(s+9))

_ = control.root_locus(sys_auto)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ## (b)
#
# There are two areas where the roots are complex so there will be two $K_2$ values corresponding with complex roots where $\zeta=0.707$.
#
# I *might* work the rest of this out later. The important thing is just to practice calculating and sketching root loci.

# %% [markdown]
# # P7.6
#
# The characteristic equation is:
#
# $$1+K\frac{(s^2+6s+11.25)(s+1)}{(s+4.5)(s+1.25)(s-0.5)(s-0.25)}=0$$

# %%
sys_satellite=((s**2+6*s+11.25)*(s+1))/((s+4.5)*(s+1.25)*(s-0.5)*(s-0.25))

_ = control.root_locus(sys_satellite)
# Out:
# <img src="data:image/png;base64,..." width="600">
